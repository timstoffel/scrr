# %%
from bokeh.plotting import figure, output_file, show
from bokeh.io import push_notebook, show, output_notebook, export_png
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.models.glyphs import VArea
from bokeh.models.tools import HoverTool
import bokeh.palettes
from bokeh.transform import factor_cmap

import pandas as pd

df = pd.read_csv('Results/ab-export-2020-01-09-16-31-53.csv')
df = df.replace(-1, 0)
print(df)
# Out:
#       runtime      image_name ressource_limit  number_of_targets  targetId  \
# 0     default        go-httpd         default                  1         1
# 1     default        go-httpd         default                  1         1
# 2     default        go-httpd         default                  1         1
# 3     default        go-httpd         default                  1         1
# 4     default        go-httpd         default                  1         1
# ...       ...             ...             ...                ...       ...
# 4665    runsc  python-tornado         default                  8         4
# 4666    runsc  python-tornado         default                  8         5
# 4667    runsc  python-tornado         default                  8         6
# 4668    runsc  python-tornado         default                  8         7
# 4669    runsc  python-tornado         default                  8         8
#
#       repeat  completed_requests  failed_requests  requests_per_second  \
# 0          1             1000000                0             21660.48
# 1         10             1000000                0             22048.57
# 2          2             1000000                0             21929.31
# 3          3             1000000                0             21831.74
# 4          4             1000000                0             21893.28
# ...      ...                 ...              ...                  ...
# 4665       9               32777                0               546.28
# 4666       9               33253                0               554.21
# 4667       9               30001                0               500.02
# 4668       9               31303                0               521.71
# 4669       9               31840                0               530.66
#
#       request_duration                                           filepath
# 0               46.167  /opt/auswertung/Raw/apache_benchmark/default/d...
# 1               45.354  /opt/auswertung/Raw/apache_benchmark/default/d...
# 2               45.601  /opt/auswertung/Raw/apache_benchmark/default/d...
# 3               45.805  /opt/auswertung/Raw/apache_benchmark/default/d...
# 4               45.676  /opt/auswertung/Raw/apache_benchmark/default/d...
# ...                ...                                                ...
# 4665            60.001  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4666            60.001  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4667            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4668            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4669            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
#
# [4670 rows x 11 columns]

# %%
# Block für node-express
filter_node = df[df['image_name'] == 'node-express']
print(filter_node)
# Out:
#       runtime    image_name ressource_limit  number_of_targets  targetId  \
# 320   default  node-express         default                  1         1
# 321   default  node-express         default                  1         1
# 322   default  node-express         default                  1         1
# 323   default  node-express         default                  1         1
# 324   default  node-express         default                  1         1
# ...       ...           ...             ...                ...       ...
# 4345    runsc  node-express         default                  8         4
# 4346    runsc  node-express         default                  8         5
# 4347    runsc  node-express         default                  8         6
# 4348    runsc  node-express         default                  8         7
# 4349    runsc  node-express         default                  8         8
#
#       repeat  completed_requests  failed_requests  requests_per_second  \
# 320        1              463838                0              7730.63
# 321       10              461201                0              7686.68
# 322        2              460557                0              7675.95
# 323        3              456381                0              7606.35
# 324        4              456779                0              7612.98
# ...      ...                 ...              ...                  ...
# 4345       9               72664                0              1211.07
# 4346       9               69580                0              1159.65
# 4347       9               72136                0              1202.26
# 4348       9               75575                0              1259.58
# 4349       9               73543                0              1225.64
#
#       request_duration                                           filepath
# 320             60.000  /opt/auswertung/Raw/apache_benchmark/default/d...
# 321             60.000  /opt/auswertung/Raw/apache_benchmark/default/d...
# 322             60.000  /opt/auswertung/Raw/apache_benchmark/default/d...
# 323             60.000  /opt/auswertung/Raw/apache_benchmark/default/d...
# 324             60.000  /opt/auswertung/Raw/apache_benchmark/default/d...
# ...                ...                                                ...
# 4345            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4346            60.001  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4347            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4348            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4349            60.004  /opt/auswertung/Raw/apache_benchmark/default/r...
#
# [1600 rows x 11 columns]

# %%
grouped_node = filter_node.groupby(['runtime', 'number_of_targets', 'repeat'])['requests_per_second'].sum().reset_index(name='sum_requests_per_second')
print(grouped_node)

grouped_sum = grouped_node.groupby(['runtime', 'number_of_targets'])['sum_requests_per_second'].mean().reset_index(name='mean_requests_per_second')
print(grouped_sum)

grouped_min = grouped_node.groupby(['runtime', 'number_of_targets'])['sum_requests_per_second'].min().reset_index(name='min_requests_per_second')
print(grouped_min)

grouped_max = grouped_node.groupby(['runtime', 'number_of_targets'])['sum_requests_per_second'].max().reset_index(name='max_requests_per_second')
print(grouped_max)
# Out:
#      runtime  number_of_targets  repeat  sum_requests_per_second
# 0    default                  1       1                  7730.63
# 1    default                  1       2                  7675.95
# 2    default                  1       3                  7606.35
# 3    default                  1       4                  7612.98
# 4    default                  1       5                  7728.28
# ..       ...                ...     ...                      ...
# 295    runsc                 13       6                  9996.63
# 296    runsc                 13       7                 10066.61
# 297    runsc                 13       8                 10004.88
# 298    runsc                 13       9                 10082.31
# 299    runsc                 13      10                 10046.74
#
# [300 rows x 4 columns]
#     runtime  number_of_targets  mean_requests_per_second
# 0   default                  1                  7675.326
# 1   default                  2                 14968.736
# 2   default                  3                 21858.289
# 3   default                  5                 21295.290
# 4   default                  8                 21248.845
# 5   default                 13                 20914.814
# 6      kata                  1                  6332.314
# 7      kata                  2                 12230.592
# 8      kata                  3                 17326.933
# 9      kata                  5                 21914.435
# 10     kata                  8                 21372.421
# 11     kata                 13                 20738.580
# 12   katafc                  1                  4436.238
# 13   katafc                  2                  8412.466
# 14   katafc                  3                 12101.404
# 15   katafc                  5                 13194.914
# 16   katafc                  8                 12842.245
# 17   katafc                 13                 10469.388
# 18    runnc                  1                     0.000
# 19    runnc                  2                     0.000
# 20    runnc                  3                     0.000
# 21    runnc                  5                     0.000
# 22    runnc                  8                     0.000
# 23    runnc                 13                     0.000
# 24    runsc                  1                  2683.798
# 25    runsc                  2                  4994.558
# 26    runsc                  3                  7052.959
# 27    runsc                  5                  9864.089
# 28    runsc                  8                  9615.042
# 29    runsc                 13                 10057.445
#     runtime  number_of_targets  min_requests_per_second
# 0   default                  1                  7604.87
# 1   default                  2                 14918.41
# 2   default                  3                 21768.02
# 3   default                  5                 21202.10
# 4   default                  8                 21154.21
# 5   default                 13                 20798.69
# 6      kata                  1                  6072.11
# 7      kata                  2                 12059.08
# 8      kata                  3                 16059.46
# 9      kata                  5                 21545.11
# 10     kata                  8                 21051.40
# 11     kata                 13                 20319.18
# 12   katafc                  1                  4164.19
# 13   katafc                  2                  8010.20
# 14   katafc                  3                 11949.81
# 15   katafc                  5                 12744.23
# 16   katafc                  8                 12667.83
# 17   katafc                 13                  9777.40
# 18    runnc                  1                     0.00
# 19    runnc                  2                     0.00
# 20    runnc                  3                     0.00
# 21    runnc                  5                     0.00
# 22    runnc                  8                     0.00
# 23    runnc                 13                     0.00
# 24    runsc                  1                  2566.06
# 25    runsc                  2                  4902.04
# 26    runsc                  3                  6967.66
# 27    runsc                  5                  9821.17
# 28    runsc                  8                  9585.57
# 29    runsc                 13                  9996.63
#     runtime  number_of_targets  max_requests_per_second
# 0   default                  1                  7735.21
# 1   default                  2                 15017.79
# 2   default                  3                 21929.50
# 3   default                  5                 21445.32
# 4   default                  8                 21330.02
# 5   default                 13                 21022.68
# 6      kata                  1                  6471.69
# 7      kata                  2                 12426.01
# 8      kata                  3                 17670.11
# 9      kata                  5                 22148.54
# 10     kata                  8                 21789.36
# 11     kata                 13                 21174.79
# 12   katafc                  1                  4552.79
# 13   katafc                  2                  8569.03
# 14   katafc                  3                 12255.57
# 15   katafc                  5                 13472.37
# 16   katafc                  8                 12977.11
# 17   katafc                 13                 11191.86
# 18    runnc                  1                     0.00
# 19    runnc                  2                     0.00
# 20    runnc                  3                     0.00
# 21    runnc                  5                     0.00
# 22    runnc                  8                     0.00
# 23    runnc                 13                     0.00
# 24    runsc                  1                  2782.03
# 25    runsc                  2                  5045.27
# 26    runsc                  3                  7142.37
# 27    runsc                  5                  9904.94
# 28    runsc                  8                  9657.38
# 29    runsc                 13                 10211.43

# %%
# Filter auf default

default_sum = grouped_sum[grouped_sum['runtime'] == 'default']
default_sum = default_sum[['number_of_targets', 'mean_requests_per_second']]
print(default_sum)

default_min = grouped_min[grouped_min['runtime'] == 'default']
default_min = default_min[['number_of_targets', 'min_requests_per_second']]
print(default_min)

default_max = grouped_max[grouped_max['runtime'] == 'default']
default_max = default_max[['number_of_targets', 'max_requests_per_second']]
print(default_max)

default_data = pd.merge(default_sum, default_min, on='number_of_targets')
default_data = pd.merge(default_data, default_max, how='outer', on='number_of_targets')
print(default_data)


# Filter auf kata

kata_sum = grouped_sum[grouped_sum['runtime'] == 'kata']
kata_sum = kata_sum[['number_of_targets', 'mean_requests_per_second']]
print(kata_sum)

kata_min = grouped_min[grouped_min['runtime'] == 'kata']
kata_min = kata_min[['number_of_targets', 'min_requests_per_second']]
print(kata_min)

kata_max = grouped_max[grouped_max['runtime'] == 'kata']
kata_max = kata_max[['number_of_targets', 'max_requests_per_second']]
print(kata_max)

kata_data = pd.merge(kata_sum, kata_min, on='number_of_targets')
kata_data = pd.merge(kata_data, kata_max, how='outer', on='number_of_targets')
print(kata_data)

# Filter auf katafc

katafc_sum = grouped_sum[grouped_sum['runtime'] == 'katafc']
katafc_sum = katafc_sum[['number_of_targets', 'mean_requests_per_second']]
print(katafc_sum)

katafc_min = grouped_min[grouped_min['runtime'] == 'katafc']
katafc_min = katafc_min[['number_of_targets', 'min_requests_per_second']]
print(katafc_min)

katafc_max = grouped_max[grouped_max['runtime'] == 'katafc']
katafc_max = katafc_max[['number_of_targets', 'max_requests_per_second']]
print(katafc_max)

katafc_data = pd.merge(katafc_sum, katafc_min, on='number_of_targets')
katafc_data = pd.merge(katafc_data, katafc_max, how='outer', on='number_of_targets')
print(katafc_data)

# Filter auf runsc

runsc_sum = grouped_sum[grouped_sum['runtime'] == 'runsc']
runsc_sum = runsc_sum[['number_of_targets', 'mean_requests_per_second']]
print(runsc_sum)

runsc_min = grouped_min[grouped_min['runtime'] == 'runsc']
runsc_min = runsc_min[['number_of_targets', 'min_requests_per_second']]
print(runsc_min)

runsc_max = grouped_max[grouped_max['runtime'] == 'runsc']
runsc_max = runsc_max[['number_of_targets', 'max_requests_per_second']]
print(runsc_max)

runsc_data = pd.merge(runsc_sum, runsc_min, on='number_of_targets')
runsc_data = pd.merge(runsc_data, runsc_max, how='outer', on='number_of_targets')
print(runsc_data)
# Out:
#    number_of_targets  mean_requests_per_second
# 0                  1                  7675.326
# 1                  2                 14968.736
# 2                  3                 21858.289
# 3                  5                 21295.290
# 4                  8                 21248.845
# 5                 13                 20914.814
#    number_of_targets  min_requests_per_second
# 0                  1                  7604.87
# 1                  2                 14918.41
# 2                  3                 21768.02
# 3                  5                 21202.10
# 4                  8                 21154.21
# 5                 13                 20798.69
#    number_of_targets  max_requests_per_second
# 0                  1                  7735.21
# 1                  2                 15017.79
# 2                  3                 21929.50
# 3                  5                 21445.32
# 4                  8                 21330.02
# 5                 13                 21022.68
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                  7675.326                  7604.87
# 1                  2                 14968.736                 14918.41
# 2                  3                 21858.289                 21768.02
# 3                  5                 21295.290                 21202.10
# 4                  8                 21248.845                 21154.21
# 5                 13                 20914.814                 20798.69
#
#    max_requests_per_second
# 0                  7735.21
# 1                 15017.79
# 2                 21929.50
# 3                 21445.32
# 4                 21330.02
# 5                 21022.68
#     number_of_targets  mean_requests_per_second
# 6                   1                  6332.314
# 7                   2                 12230.592
# 8                   3                 17326.933
# 9                   5                 21914.435
# 10                  8                 21372.421
# 11                 13                 20738.580
#     number_of_targets  min_requests_per_second
# 6                   1                  6072.11
# 7                   2                 12059.08
# 8                   3                 16059.46
# 9                   5                 21545.11
# 10                  8                 21051.40
# 11                 13                 20319.18
#     number_of_targets  max_requests_per_second
# 6                   1                  6471.69
# 7                   2                 12426.01
# 8                   3                 17670.11
# 9                   5                 22148.54
# 10                  8                 21789.36
# 11                 13                 21174.79
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                  6332.314                  6072.11
# 1                  2                 12230.592                 12059.08
# 2                  3                 17326.933                 16059.46
# 3                  5                 21914.435                 21545.11
# 4                  8                 21372.421                 21051.40
# 5                 13                 20738.580                 20319.18
#
#    max_requests_per_second
# 0                  6471.69
# 1                 12426.01
# 2                 17670.11
# 3                 22148.54
# 4                 21789.36
# 5                 21174.79
#     number_of_targets  mean_requests_per_second
# 12                  1                  4436.238
# 13                  2                  8412.466
# 14                  3                 12101.404
# 15                  5                 13194.914
# 16                  8                 12842.245
# 17                 13                 10469.388
#     number_of_targets  min_requests_per_second
# 12                  1                  4164.19
# 13                  2                  8010.20
# 14                  3                 11949.81
# 15                  5                 12744.23
# 16                  8                 12667.83
# 17                 13                  9777.40
#     number_of_targets  max_requests_per_second
# 12                  1                  4552.79
# 13                  2                  8569.03
# 14                  3                 12255.57
# 15                  5                 13472.37
# 16                  8                 12977.11
# 17                 13                 11191.86
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                  4436.238                  4164.19
# 1                  2                  8412.466                  8010.20
# 2                  3                 12101.404                 11949.81
# 3                  5                 13194.914                 12744.23
# 4                  8                 12842.245                 12667.83
# 5                 13                 10469.388                  9777.40
#
#    max_requests_per_second
# 0                  4552.79
# 1                  8569.03
# 2                 12255.57
# 3                 13472.37
# 4                 12977.11
# 5                 11191.86
#     number_of_targets  mean_requests_per_second
# 24                  1                  2683.798
# 25                  2                  4994.558
# 26                  3                  7052.959
# 27                  5                  9864.089
# 28                  8                  9615.042
# 29                 13                 10057.445
#     number_of_targets  min_requests_per_second
# 24                  1                  2566.06
# 25                  2                  4902.04
# 26                  3                  6967.66
# 27                  5                  9821.17
# 28                  8                  9585.57
# 29                 13                  9996.63
#     number_of_targets  max_requests_per_second
# 24                  1                  2782.03
# 25                  2                  5045.27
# 26                  3                  7142.37
# 27                  5                  9904.94
# 28                  8                  9657.38
# 29                 13                 10211.43
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                  2683.798                  2566.06
# 1                  2                  4994.558                  4902.04
# 2                  3                  7052.959                  6967.66
# 3                  5                  9864.089                  9821.17
# 4                  8                  9615.042                  9585.57
# 5                 13                 10057.445                  9996.63
#
#    max_requests_per_second
# 0                  2782.03
# 1                  5045.27
# 2                  7142.37
# 3                  9904.94
# 4                  9657.38
# 5                 10211.43

# %%
default_source = ColumnDataSource(default_data)
print(default_source.data)

kata_source = ColumnDataSource(kata_data)
print(kata_source.data)

katafc_source = ColumnDataSource(katafc_data)
print(katafc_source.data)

runsc_source = ColumnDataSource(runsc_data)
print(runsc_source.data)
# Out:
# {'index': array([0, 1, 2, 3, 4, 5]), 'number_of_targets': array([ 1,  2,  3,  5,  8, 13]), 'mean_requests_per_second': array([ 7675.326, 14968.736, 21858.289, 21295.29 , 21248.845, 20914.814]), 'min_requests_per_second': array([ 7604.87, 14918.41, 21768.02, 21202.1 , 21154.21, 20798.69]), 'max_requests_per_second': array([ 7735.21, 15017.79, 21929.5 , 21445.32, 21330.02, 21022.68])}
# {'index': array([0, 1, 2, 3, 4, 5]), 'number_of_targets': array([ 1,  2,  3,  5,  8, 13]), 'mean_requests_per_second': array([ 6332.314, 12230.592, 17326.933, 21914.435, 21372.421, 20738.58 ]), 'min_requests_per_second': array([ 6072.11, 12059.08, 16059.46, 21545.11, 21051.4 , 20319.18]), 'max_requests_per_second': array([ 6471.69, 12426.01, 17670.11, 22148.54, 21789.36, 21174.79])}
# {'index': array([0, 1, 2, 3, 4, 5]), 'number_of_targets': array([ 1,  2,  3,  5,  8, 13]), 'mean_requests_per_second': array([ 4436.238,  8412.466, 12101.404, 13194.914, 12842.245, 10469.388]), 'min_requests_per_second': array([ 4164.19,  8010.2 , 11949.81, 12744.23, 12667.83,  9777.4 ]), 'max_requests_per_second': array([ 4552.79,  8569.03, 12255.57, 13472.37, 12977.11, 11191.86])}
# {'index': array([0, 1, 2, 3, 4, 5]), 'number_of_targets': array([ 1,  2,  3,  5,  8, 13]), 'mean_requests_per_second': array([ 2683.798,  4994.558,  7052.959,  9864.089,  9615.042, 10057.445]), 'min_requests_per_second': array([2566.06, 4902.04, 6967.66, 9821.17, 9585.57, 9996.63]), 'max_requests_per_second': array([ 2782.03,  5045.27,  7142.37,  9904.94,  9657.38, 10211.43])}

# %%
p = figure(x_axis_type='linear', width=1500)

# Linien für default runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][1], fill_alpha=0.3)
p.add_glyph(default_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=default_source, color=bokeh.palettes.d3['Category20'][12][0], legend_label='default (Docker)')

# Linien für kata runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][2], fill_alpha=0.3)
p.add_glyph(kata_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=kata_source, color=bokeh.palettes.d3['Category20'][12][3], legend_label='kata')

# Linien für katafc runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][4], fill_alpha=0.3)
p.add_glyph(katafc_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=katafc_source, color=bokeh.palettes.d3['Category20'][12][5], legend_label='katafc')

# Linien für runsc runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][6], fill_alpha=0.3)
p.add_glyph(runsc_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=runsc_source, color=bokeh.palettes.d3['Category20'][12][7], legend_label='runsc (gVisor)')



#p.line(x='number_of_targets', y='min_requests_per_second', line_width=2, source=default_source, color=bokeh.palettes.d3['Category20c'][12][2], legend_label='default-min')
#p.line(x='number_of_targets', y='max_requests_per_second', line_width=2, source=default_source, color=bokeh.palettes.d3['Category20c'][12][3], legend_label='default-max')

#p.varea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', source=default_source)



colors = bokeh.palettes.d3['Category20c'][12]

p.title.text ='Requests pro Sekunde nach Anzahl der parellen Container für node'
p.xaxis.axis_label = 'Anzahl an parallelen Containern'
p.yaxis.axis_label = 'Requests pro Sekunde'

output_file("requests_pro_sec_anzahl_container_node.html")
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1123">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d713eae5-d6d8-4424-8baf-b69a77244828" data-root-id="1005"></div>
