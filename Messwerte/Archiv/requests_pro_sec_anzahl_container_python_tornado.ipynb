# %%
from bokeh.plotting import figure, output_file, show
from bokeh.io import push_notebook, show, output_notebook, export_png
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.models.glyphs import VArea
from bokeh.models.tools import HoverTool
import bokeh.palettes
from bokeh.transform import factor_cmap

import pandas as pd

df = pd.read_csv('Results/ab-export-2020-01-09-16-31-53.csv')
df = df.replace(-1, 0)
print(df)
# Out:
#       runtime      image_name ressource_limit  number_of_targets  targetId  \
# 0     default        go-httpd         default                  1         1
# 1     default        go-httpd         default                  1         1
# 2     default        go-httpd         default                  1         1
# 3     default        go-httpd         default                  1         1
# 4     default        go-httpd         default                  1         1
# ...       ...             ...             ...                ...       ...
# 4665    runsc  python-tornado         default                  8         4
# 4666    runsc  python-tornado         default                  8         5
# 4667    runsc  python-tornado         default                  8         6
# 4668    runsc  python-tornado         default                  8         7
# 4669    runsc  python-tornado         default                  8         8
#
#       repeat  completed_requests  failed_requests  requests_per_second  \
# 0          1             1000000                0             21660.48
# 1         10             1000000                0             22048.57
# 2          2             1000000                0             21929.31
# 3          3             1000000                0             21831.74
# 4          4             1000000                0             21893.28
# ...      ...                 ...              ...                  ...
# 4665       9               32777                0               546.28
# 4666       9               33253                0               554.21
# 4667       9               30001                0               500.02
# 4668       9               31303                0               521.71
# 4669       9               31840                0               530.66
#
#       request_duration                                           filepath
# 0               46.167  /opt/auswertung/Raw/apache_benchmark/default/d...
# 1               45.354  /opt/auswertung/Raw/apache_benchmark/default/d...
# 2               45.601  /opt/auswertung/Raw/apache_benchmark/default/d...
# 3               45.805  /opt/auswertung/Raw/apache_benchmark/default/d...
# 4               45.676  /opt/auswertung/Raw/apache_benchmark/default/d...
# ...                ...                                                ...
# 4665            60.001  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4666            60.001  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4667            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4668            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4669            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
#
# [4670 rows x 11 columns]

# %%
# Block für python-tornado
filter_py = df[df['image_name'] == 'python-tornado']
print(filter_py)
# Out:
#       runtime      image_name ressource_limit  number_of_targets  targetId  \
# 640   default  python-tornado         default                  1         1
# 641   default  python-tornado         default                  1         1
# 642   default  python-tornado         default                  1         1
# 643   default  python-tornado         default                  1         1
# 644   default  python-tornado         default                  1         1
# ...       ...             ...             ...                ...       ...
# 4665    runsc  python-tornado         default                  8         4
# 4666    runsc  python-tornado         default                  8         5
# 4667    runsc  python-tornado         default                  8         6
# 4668    runsc  python-tornado         default                  8         7
# 4669    runsc  python-tornado         default                  8         8
#
#       repeat  completed_requests  failed_requests  requests_per_second  \
# 640        1              109186                0              1819.64
# 641       10              109296                0              1821.60
# 642        2              108701                0              1811.68
# 643        3              112258                0              1870.86
# 644        4              109546                0              1825.77
# ...      ...                 ...              ...                  ...
# 4665       9               32777                0               546.28
# 4666       9               33253                0               554.21
# 4667       9               30001                0               500.02
# 4668       9               31303                0               521.71
# 4669       9               31840                0               530.66
#
#       request_duration                                           filepath
# 640             60.004  /opt/auswertung/Raw/apache_benchmark/default/d...
# 641             60.000  /opt/auswertung/Raw/apache_benchmark/default/d...
# 642             60.000  /opt/auswertung/Raw/apache_benchmark/default/d...
# 643             60.003  /opt/auswertung/Raw/apache_benchmark/default/d...
# 644             60.000  /opt/auswertung/Raw/apache_benchmark/default/d...
# ...                ...                                                ...
# 4665            60.001  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4666            60.001  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4667            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4668            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4669            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
#
# [1470 rows x 11 columns]

# %%
grouped_py = filter_py.groupby(['runtime', 'number_of_targets', 'repeat'])['requests_per_second'].sum().reset_index(name='sum_requests_per_second')
print(grouped_py)

grouped_sum = grouped_py.groupby(['runtime', 'number_of_targets'])['sum_requests_per_second'].mean().reset_index(name='mean_requests_per_second')
print(grouped_sum)

grouped_min = grouped_py.groupby(['runtime', 'number_of_targets'])['sum_requests_per_second'].min().reset_index(name='min_requests_per_second')
print(grouped_min)

grouped_max = grouped_py.groupby(['runtime', 'number_of_targets'])['sum_requests_per_second'].max().reset_index(name='max_requests_per_second')
print(grouped_max)
# Out:
#      runtime  number_of_targets  repeat  sum_requests_per_second
# 0    default                  1       1                  1819.64
# 1    default                  1       2                  1811.68
# 2    default                  1       3                  1870.86
# 3    default                  1       4                  1825.77
# 4    default                  1       5                  1863.54
# ..       ...                ...     ...                      ...
# 285    runsc                 13       6                  4262.13
# 286    runsc                 13       7                  4268.21
# 287    runsc                 13       8                  4231.15
# 288    runsc                 13       9                  4267.39
# 289    runsc                 13      10                  4250.18
#
# [290 rows x 4 columns]
#     runtime  number_of_targets  mean_requests_per_second
# 0   default                  1                  1821.983
# 1   default                  2                  3586.664
# 2   default                  3                  5246.318
# 3   default                  5                  7258.391
# 4   default                  8                  7538.694
# 5   default                 13                  7872.459
# 6      kata                  1                  1786.133
# 7      kata                  2                  3379.610
# 8      kata                  3                  4715.644
# 9      kata                  5                  6042.269
# 10     kata                  8                  5729.989
# 11     kata                 13                  5262.401
# 12   katafc                  1                  1473.146
# 13   katafc                  2                  2801.812
# 14   katafc                  3                  3827.213
# 15   katafc                  5                  4817.644
# 16   katafc                  8                  4612.231
# 17   katafc                 13                  4167.608
# 18    runnc                  1                  1568.676
# 19    runnc                  2                  3472.505
# 20    runnc                  3                  4850.043
# 21    runnc                  5                  7332.682
# 22    runnc                  8                  8040.436
# 23    runsc                  1                   675.538
# 24    runsc                  2                  2075.186
# 25    runsc                  3                  3014.907
# 26    runsc                  5                  4419.848
# 27    runsc                  8                  4171.419
# 28    runsc                 13                  4259.559
#     runtime  number_of_targets  min_requests_per_second
# 0   default                  1                  1670.30
# 1   default                  2                  3537.18
# 2   default                  3                  5213.30
# 3   default                  5                  7201.31
# 4   default                  8                  7488.26
# 5   default                 13                  7830.18
# 6      kata                  1                  1756.33
# 7      kata                  2                  3254.64
# 8      kata                  3                  4476.25
# 9      kata                  5                  5809.42
# 10     kata                  8                  5661.93
# 11     kata                 13                  5108.96
# 12   katafc                  1                  1289.21
# 13   katafc                  2                  2701.92
# 14   katafc                  3                  3567.50
# 15   katafc                  5                  4741.00
# 16   katafc                  8                  4579.90
# 17   katafc                 13                  4103.66
# 18    runnc                  1                     0.00
# 19    runnc                  2                  1852.66
# 20    runnc                  3                  3570.16
# 21    runnc                  5                  5895.53
# 22    runnc                  8                  6641.58
# 23    runsc                  1                   621.66
# 24    runsc                  2                  2064.99
# 25    runsc                  3                  2997.01
# 26    runsc                  5                  4405.41
# 27    runsc                  8                  4149.83
# 28    runsc                 13                  4231.15
#     runtime  number_of_targets  max_requests_per_second
# 0   default                  1                  1870.86
# 1   default                  2                  3613.30
# 2   default                  3                  5290.37
# 3   default                  5                  7344.40
# 4   default                  8                  7564.67
# 5   default                 13                  7908.51
# 6      kata                  1                  1830.23
# 7      kata                  2                  3424.95
# 8      kata                  3                  4811.12
# 9      kata                  5                  6285.36
# 10     kata                  8                  5793.23
# 11     kata                 13                  5441.38
# 12   katafc                  1                  1547.07
# 13   katafc                  2                  2870.41
# 14   katafc                  3                  3998.87
# 15   katafc                  5                  4890.67
# 16   katafc                  8                  4641.23
# 17   katafc                 13                  4231.12
# 18    runnc                  1                  2053.84
# 19    runnc                  2                  3927.95
# 20    runnc                  3                  5716.73
# 21    runnc                  5                  7925.84
# 22    runnc                  8                  8415.69
# 23    runsc                  1                   739.80
# 24    runsc                  2                  2086.29
# 25    runsc                  3                  3033.28
# 26    runsc                  5                  4434.58
# 27    runsc                  8                  4189.34
# 28    runsc                 13                  4284.27

# %%
# Filter auf default

default_sum = grouped_sum[grouped_sum['runtime'] == 'default']
default_sum = default_sum[['number_of_targets', 'mean_requests_per_second']]
print(default_sum)

default_min = grouped_min[grouped_min['runtime'] == 'default']
default_min = default_min[['number_of_targets', 'min_requests_per_second']]
print(default_min)

default_max = grouped_max[grouped_max['runtime'] == 'default']
default_max = default_max[['number_of_targets', 'max_requests_per_second']]
print(default_max)

default_data = pd.merge(default_sum, default_min, on='number_of_targets')
default_data = pd.merge(default_data, default_max, how='outer', on='number_of_targets')
print(default_data)


# Filter auf kata

kata_sum = grouped_sum[grouped_sum['runtime'] == 'kata']
kata_sum = kata_sum[['number_of_targets', 'mean_requests_per_second']]
print(kata_sum)

kata_min = grouped_min[grouped_min['runtime'] == 'kata']
kata_min = kata_min[['number_of_targets', 'min_requests_per_second']]
print(kata_min)

kata_max = grouped_max[grouped_max['runtime'] == 'kata']
kata_max = kata_max[['number_of_targets', 'max_requests_per_second']]
print(kata_max)

kata_data = pd.merge(kata_sum, kata_min, on='number_of_targets')
kata_data = pd.merge(kata_data, kata_max, how='outer', on='number_of_targets')
print(kata_data)

# Filter auf katafc

katafc_sum = grouped_sum[grouped_sum['runtime'] == 'katafc']
katafc_sum = katafc_sum[['number_of_targets', 'mean_requests_per_second']]
print(katafc_sum)

katafc_min = grouped_min[grouped_min['runtime'] == 'katafc']
katafc_min = katafc_min[['number_of_targets', 'min_requests_per_second']]
print(katafc_min)

katafc_max = grouped_max[grouped_max['runtime'] == 'katafc']
katafc_max = katafc_max[['number_of_targets', 'max_requests_per_second']]
print(katafc_max)

katafc_data = pd.merge(katafc_sum, katafc_min, on='number_of_targets')
katafc_data = pd.merge(katafc_data, katafc_max, how='outer', on='number_of_targets')
print(katafc_data)

# Filter auf runsc

runsc_sum = grouped_sum[grouped_sum['runtime'] == 'runsc']
runsc_sum = runsc_sum[['number_of_targets', 'mean_requests_per_second']]
print(runsc_sum)

runsc_min = grouped_min[grouped_min['runtime'] == 'runsc']
runsc_min = runsc_min[['number_of_targets', 'min_requests_per_second']]
print(runsc_min)

runsc_max = grouped_max[grouped_max['runtime'] == 'runsc']
runsc_max = runsc_max[['number_of_targets', 'max_requests_per_second']]
print(runsc_max)

runsc_data = pd.merge(runsc_sum, runsc_min, on='number_of_targets')
runsc_data = pd.merge(runsc_data, runsc_max, how='outer', on='number_of_targets')
print(runsc_data)

# Filter auf runnc

runnc_sum = grouped_sum[grouped_sum['runtime'] == 'runnc']
runnc_sum = runnc_sum[['number_of_targets', 'mean_requests_per_second']]
print(runnc_sum)

runnc_min = grouped_min[grouped_min['runtime'] == 'runnc']
runnc_min = runnc_min[['number_of_targets', 'min_requests_per_second']]
print(runnc_min)

runnc_max = grouped_max[grouped_max['runtime'] == 'runnc']
runnc_max = runnc_max[['number_of_targets', 'max_requests_per_second']]
print(runnc_max)

runnc_data = pd.merge(runnc_sum, runnc_min, on='number_of_targets')
runnc_data = pd.merge(runnc_data, runnc_max, how='outer', on='number_of_targets')
print(runnc_data)
# Out:
#    number_of_targets  mean_requests_per_second
# 0                  1                  1821.983
# 1                  2                  3586.664
# 2                  3                  5246.318
# 3                  5                  7258.391
# 4                  8                  7538.694
# 5                 13                  7872.459
#    number_of_targets  min_requests_per_second
# 0                  1                  1670.30
# 1                  2                  3537.18
# 2                  3                  5213.30
# 3                  5                  7201.31
# 4                  8                  7488.26
# 5                 13                  7830.18
#    number_of_targets  max_requests_per_second
# 0                  1                  1870.86
# 1                  2                  3613.30
# 2                  3                  5290.37
# 3                  5                  7344.40
# 4                  8                  7564.67
# 5                 13                  7908.51
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                  1821.983                  1670.30
# 1                  2                  3586.664                  3537.18
# 2                  3                  5246.318                  5213.30
# 3                  5                  7258.391                  7201.31
# 4                  8                  7538.694                  7488.26
# 5                 13                  7872.459                  7830.18
#
#    max_requests_per_second
# 0                  1870.86
# 1                  3613.30
# 2                  5290.37
# 3                  7344.40
# 4                  7564.67
# 5                  7908.51
#     number_of_targets  mean_requests_per_second
# 6                   1                  1786.133
# 7                   2                  3379.610
# 8                   3                  4715.644
# 9                   5                  6042.269
# 10                  8                  5729.989
# 11                 13                  5262.401
#     number_of_targets  min_requests_per_second
# 6                   1                  1756.33
# 7                   2                  3254.64
# 8                   3                  4476.25
# 9                   5                  5809.42
# 10                  8                  5661.93
# 11                 13                  5108.96
#     number_of_targets  max_requests_per_second
# 6                   1                  1830.23
# 7                   2                  3424.95
# 8                   3                  4811.12
# 9                   5                  6285.36
# 10                  8                  5793.23
# 11                 13                  5441.38
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                  1786.133                  1756.33
# 1                  2                  3379.610                  3254.64
# 2                  3                  4715.644                  4476.25
# 3                  5                  6042.269                  5809.42
# 4                  8                  5729.989                  5661.93
# 5                 13                  5262.401                  5108.96
#
#    max_requests_per_second
# 0                  1830.23
# 1                  3424.95
# 2                  4811.12
# 3                  6285.36
# 4                  5793.23
# 5                  5441.38
#     number_of_targets  mean_requests_per_second
# 12                  1                  1473.146
# 13                  2                  2801.812
# 14                  3                  3827.213
# 15                  5                  4817.644
# 16                  8                  4612.231
# 17                 13                  4167.608
#     number_of_targets  min_requests_per_second
# 12                  1                  1289.21
# 13                  2                  2701.92
# 14                  3                  3567.50
# 15                  5                  4741.00
# 16                  8                  4579.90
# 17                 13                  4103.66
#     number_of_targets  max_requests_per_second
# 12                  1                  1547.07
# 13                  2                  2870.41
# 14                  3                  3998.87
# 15                  5                  4890.67
# 16                  8                  4641.23
# 17                 13                  4231.12
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                  1473.146                  1289.21
# 1                  2                  2801.812                  2701.92
# 2                  3                  3827.213                  3567.50
# 3                  5                  4817.644                  4741.00
# 4                  8                  4612.231                  4579.90
# 5                 13                  4167.608                  4103.66
#
#    max_requests_per_second
# 0                  1547.07
# 1                  2870.41
# 2                  3998.87
# 3                  4890.67
# 4                  4641.23
# 5                  4231.12
#     number_of_targets  mean_requests_per_second
# 23                  1                   675.538
# 24                  2                  2075.186
# 25                  3                  3014.907
# 26                  5                  4419.848
# 27                  8                  4171.419
# 28                 13                  4259.559
#     number_of_targets  min_requests_per_second
# 23                  1                   621.66
# 24                  2                  2064.99
# 25                  3                  2997.01
# 26                  5                  4405.41
# 27                  8                  4149.83
# 28                 13                  4231.15
#     number_of_targets  max_requests_per_second
# 23                  1                   739.80
# 24                  2                  2086.29
# 25                  3                  3033.28
# 26                  5                  4434.58
# 27                  8                  4189.34
# 28                 13                  4284.27
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                   675.538                   621.66
# 1                  2                  2075.186                  2064.99
# 2                  3                  3014.907                  2997.01
# 3                  5                  4419.848                  4405.41
# 4                  8                  4171.419                  4149.83
# 5                 13                  4259.559                  4231.15
#
#    max_requests_per_second
# 0                   739.80
# 1                  2086.29
# 2                  3033.28
# 3                  4434.58
# 4                  4189.34
# 5                  4284.27
#     number_of_targets  mean_requests_per_second
# 18                  1                  1568.676
# 19                  2                  3472.505
# 20                  3                  4850.043
# 21                  5                  7332.682
# 22                  8                  8040.436
#     number_of_targets  min_requests_per_second
# 18                  1                     0.00
# 19                  2                  1852.66
# 20                  3                  3570.16
# 21                  5                  5895.53
# 22                  8                  6641.58
#     number_of_targets  max_requests_per_second
# 18                  1                  2053.84
# 19                  2                  3927.95
# 20                  3                  5716.73
# 21                  5                  7925.84
# 22                  8                  8415.69
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                  1568.676                     0.00
# 1                  2                  3472.505                  1852.66
# 2                  3                  4850.043                  3570.16
# 3                  5                  7332.682                  5895.53
# 4                  8                  8040.436                  6641.58
#
#    max_requests_per_second
# 0                  2053.84
# 1                  3927.95
# 2                  5716.73
# 3                  7925.84
# 4                  8415.69

# %%
default_source = ColumnDataSource(default_data)
print(default_source.data)

kata_source = ColumnDataSource(kata_data)
print(kata_source.data)

katafc_source = ColumnDataSource(katafc_data)
print(katafc_source.data)

runsc_source = ColumnDataSource(runsc_data)
print(runsc_source.data)

runnc_source = ColumnDataSource(runnc_data)
print(runnc_source.data)
# Out:
# {'index': array([0, 1, 2, 3, 4, 5]), 'number_of_targets': array([ 1,  2,  3,  5,  8, 13]), 'mean_requests_per_second': array([1821.983, 3586.664, 5246.318, 7258.391, 7538.694, 7872.459]), 'min_requests_per_second': array([1670.3 , 3537.18, 5213.3 , 7201.31, 7488.26, 7830.18]), 'max_requests_per_second': array([1870.86, 3613.3 , 5290.37, 7344.4 , 7564.67, 7908.51])}
# {'index': array([0, 1, 2, 3, 4, 5]), 'number_of_targets': array([ 1,  2,  3,  5,  8, 13]), 'mean_requests_per_second': array([1786.133, 3379.61 , 4715.644, 6042.269, 5729.989, 5262.401]), 'min_requests_per_second': array([1756.33, 3254.64, 4476.25, 5809.42, 5661.93, 5108.96]), 'max_requests_per_second': array([1830.23, 3424.95, 4811.12, 6285.36, 5793.23, 5441.38])}
# {'index': array([0, 1, 2, 3, 4, 5]), 'number_of_targets': array([ 1,  2,  3,  5,  8, 13]), 'mean_requests_per_second': array([1473.146, 2801.812, 3827.213, 4817.644, 4612.231, 4167.608]), 'min_requests_per_second': array([1289.21, 2701.92, 3567.5 , 4741.  , 4579.9 , 4103.66]), 'max_requests_per_second': array([1547.07, 2870.41, 3998.87, 4890.67, 4641.23, 4231.12])}
# {'index': array([0, 1, 2, 3, 4, 5]), 'number_of_targets': array([ 1,  2,  3,  5,  8, 13]), 'mean_requests_per_second': array([ 675.538, 2075.186, 3014.907, 4419.848, 4171.419, 4259.559]), 'min_requests_per_second': array([ 621.66, 2064.99, 2997.01, 4405.41, 4149.83, 4231.15]), 'max_requests_per_second': array([ 739.8 , 2086.29, 3033.28, 4434.58, 4189.34, 4284.27])}
# {'index': array([0, 1, 2, 3, 4]), 'number_of_targets': array([1, 2, 3, 5, 8]), 'mean_requests_per_second': array([1568.676, 3472.505, 4850.043, 7332.682, 8040.436]), 'min_requests_per_second': array([   0.  , 1852.66, 3570.16, 5895.53, 6641.58]), 'max_requests_per_second': array([2053.84, 3927.95, 5716.73, 7925.84, 8415.69])}

# %%
p = figure(x_axis_type='linear', width=1500)

# Linien für default runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][1], fill_alpha=0.3)
p.add_glyph(default_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=default_source, color=bokeh.palettes.d3['Category20'][12][0], legend_label='default (Docker)')

# Linien für kata runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][2], fill_alpha=0.3)
p.add_glyph(kata_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=kata_source, color=bokeh.palettes.d3['Category20'][12][3], legend_label='kata')

# Linien für katafc runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][4], fill_alpha=0.3)
p.add_glyph(katafc_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=katafc_source, color=bokeh.palettes.d3['Category20'][12][5], legend_label='katafc')

# Linien für runsc runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][6], fill_alpha=0.3)
p.add_glyph(runsc_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=runsc_source, color=bokeh.palettes.d3['Category20'][12][7], legend_label='runsc (gVisor)')

# Linien für runnc runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][8], fill_alpha=0.3)
p.add_glyph(runnc_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=runnc_source, color=bokeh.palettes.d3['Category20'][12][9], legend_label='runnc (Nabla)')

#p.line(x='number_of_targets', y='min_requests_per_second', line_width=2, source=default_source, color=bokeh.palettes.d3['Category20c'][12][2], legend_label='default-min')
#p.line(x='number_of_targets', y='max_requests_per_second', line_width=2, source=default_source, color=bokeh.palettes.d3['Category20c'][12][3], legend_label='default-max')

#p.varea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', source=default_source)

p.legend.location = "top_left"
p.legend.click_policy="hide"

colors = bokeh.palettes.d3['Category20c'][12]

p.title.text ='Requests pro Sekunde nach Anzahl der parellen Container für python'
p.xaxis.axis_label = 'Anzahl an parallelen Containern'
p.yaxis.axis_label = 'Requests pro Sekunde'

output_file("requests_pro_sec_anzahl_container_python.html")
output_notebook()

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2341">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="bd557b13-96ac-4873-9663-ee0e20dcfe9c" data-root-id="2197"></div>
