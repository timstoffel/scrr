# %%
from bokeh.plotting import figure, output_file, show
from bokeh.io import push_notebook, show, output_notebook, export_png
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.models.glyphs import VArea
from bokeh.models.tools import HoverTool
import bokeh.palettes
from bokeh.transform import factor_cmap

import pandas as pd

df = pd.read_csv('Results/ab-export-2020-01-09-16-31-53.csv')
df = df.replace(-1, 0)
print(df)
# Out:
#       runtime      image_name ressource_limit  number_of_targets  targetId  \
# 0     default        go-httpd         default                  1         1
# 1     default        go-httpd         default                  1         1
# 2     default        go-httpd         default                  1         1
# 3     default        go-httpd         default                  1         1
# 4     default        go-httpd         default                  1         1
# ...       ...             ...             ...                ...       ...
# 4665    runsc  python-tornado         default                  8         4
# 4666    runsc  python-tornado         default                  8         5
# 4667    runsc  python-tornado         default                  8         6
# 4668    runsc  python-tornado         default                  8         7
# 4669    runsc  python-tornado         default                  8         8
#
#       repeat  completed_requests  failed_requests  requests_per_second  \
# 0          1             1000000                0             21660.48
# 1         10             1000000                0             22048.57
# 2          2             1000000                0             21929.31
# 3          3             1000000                0             21831.74
# 4          4             1000000                0             21893.28
# ...      ...                 ...              ...                  ...
# 4665       9               32777                0               546.28
# 4666       9               33253                0               554.21
# 4667       9               30001                0               500.02
# 4668       9               31303                0               521.71
# 4669       9               31840                0               530.66
#
#       request_duration                                           filepath
# 0               46.167  /opt/auswertung/Raw/apache_benchmark/default/d...
# 1               45.354  /opt/auswertung/Raw/apache_benchmark/default/d...
# 2               45.601  /opt/auswertung/Raw/apache_benchmark/default/d...
# 3               45.805  /opt/auswertung/Raw/apache_benchmark/default/d...
# 4               45.676  /opt/auswertung/Raw/apache_benchmark/default/d...
# ...                ...                                                ...
# 4665            60.001  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4666            60.001  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4667            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4668            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4669            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
#
# [4670 rows x 11 columns]

# %%
# Block für go-httpd
filter_go = df[df['image_name'] == 'go-httpd']
print(filter_go)
# Out:
#       runtime image_name ressource_limit  number_of_targets  targetId  repeat  \
# 0     default   go-httpd         default                  1         1       1
# 1     default   go-httpd         default                  1         1      10
# 2     default   go-httpd         default                  1         1       2
# 3     default   go-httpd         default                  1         1       3
# 4     default   go-httpd         default                  1         1       4
# ...       ...        ...             ...                ...       ...     ...
# 4025    runsc   go-httpd         default                  8         4       9
# 4026    runsc   go-httpd         default                  8         5       9
# 4027    runsc   go-httpd         default                  8         6       9
# 4028    runsc   go-httpd         default                  8         7       9
# 4029    runsc   go-httpd         default                  8         8       9
#
#       completed_requests  failed_requests  requests_per_second  \
# 0                1000000                0             21660.48
# 1                1000000                0             22048.57
# 2                1000000                0             21929.31
# 3                1000000                0             21831.74
# 4                1000000                0             21893.28
# ...                  ...              ...                  ...
# 4025               65608                0              1093.35
# 4026               65261                0              1087.68
# 4027               66546                0              1109.09
# 4028               67242                0              1120.70
# 4029               76826                0              1280.43
#
#       request_duration                                           filepath
# 0               46.167  /opt/auswertung/Raw/apache_benchmark/default/d...
# 1               45.354  /opt/auswertung/Raw/apache_benchmark/default/d...
# 2               45.601  /opt/auswertung/Raw/apache_benchmark/default/d...
# 3               45.805  /opt/auswertung/Raw/apache_benchmark/default/d...
# 4               45.676  /opt/auswertung/Raw/apache_benchmark/default/d...
# ...                ...                                                ...
# 4025            60.006  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4026            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4027            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4028            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
# 4029            60.000  /opt/auswertung/Raw/apache_benchmark/default/r...
#
# [1600 rows x 11 columns]

# %%
grouped_go = filter_go.groupby(['runtime', 'number_of_targets', 'repeat'])['requests_per_second'].sum().reset_index(name='sum_requests_per_second')
print(grouped_go)

grouped_sum = grouped_go.groupby(['runtime', 'number_of_targets'])['sum_requests_per_second'].mean().reset_index(name='mean_requests_per_second')
print(grouped_sum)

grouped_min = grouped_go.groupby(['runtime', 'number_of_targets'])['sum_requests_per_second'].min().reset_index(name='min_requests_per_second')
print(grouped_min)

grouped_max = grouped_go.groupby(['runtime', 'number_of_targets'])['sum_requests_per_second'].max().reset_index(name='max_requests_per_second')
print(grouped_max)
# Out:
#      runtime  number_of_targets  repeat  sum_requests_per_second
# 0    default                  1       1                 21660.48
# 1    default                  1       2                 21929.31
# 2    default                  1       3                 21831.74
# 3    default                  1       4                 21893.28
# 4    default                  1       5                 21774.17
# ..       ...                ...     ...                      ...
# 295    runsc                 13       6                  9426.99
# 296    runsc                 13       7                  9408.23
# 297    runsc                 13       8                  9376.64
# 298    runsc                 13       9                  9337.12
# 299    runsc                 13      10                  9526.62
#
# [300 rows x 4 columns]
#     runtime  number_of_targets  mean_requests_per_second
# 0   default                  1                 21762.442
# 1   default                  2                 26943.709
# 2   default                  3                 26153.097
# 3   default                  5                 25048.429
# 4   default                  8                 25206.350
# 5   default                 13                 25201.639
# 6      kata                  1                 16338.205
# 7      kata                  2                 31610.695
# 8      kata                  3                 31549.669
# 9      kata                  5                 33114.912
# 10     kata                  8                 37281.530
# 11     kata                 13                 44102.552
# 12   katafc                  1                 10096.745
# 13   katafc                  2                 17490.331
# 14   katafc                  3                 20233.842
# 15   katafc                  5                 28235.353
# 16   katafc                  8                 23497.282
# 17   katafc                 13                 21313.104
# 18    runnc                  1                  7575.650
# 19    runnc                  2                 15008.170
# 20    runnc                  3                 22012.353
# 21    runnc                  5                 31348.574
# 22    runnc                  8                 32705.744
# 23    runnc                 13                 36084.286
# 24    runsc                  1                  7735.627
# 25    runsc                  2                  8539.665
# 26    runsc                  3                  9754.796
# 27    runsc                  5                 10538.674
# 28    runsc                  8                  9159.636
# 29    runsc                 13                  9435.927
#     runtime  number_of_targets  min_requests_per_second
# 0   default                  1                 21242.61
# 1   default                  2                 26893.69
# 2   default                  3                 26009.76
# 3   default                  5                 24963.31
# 4   default                  8                 25040.27
# 5   default                 13                 24933.09
# 6      kata                  1                 15518.60
# 7      kata                  2                 31096.62
# 8      kata                  3                 31103.63
# 9      kata                  5                 32769.56
# 10     kata                  8                 36378.81
# 11     kata                 13                 43515.25
# 12   katafc                  1                  9361.14
# 13   katafc                  2                 17339.26
# 14   katafc                  3                 19863.23
# 15   katafc                  5                 27818.57
# 16   katafc                  8                 23103.44
# 17   katafc                 13                 21063.02
# 18    runnc                  1                  7466.13
# 19    runnc                  2                 14939.23
# 20    runnc                  3                 21899.77
# 21    runnc                  5                 31175.01
# 22    runnc                  8                 32455.10
# 23    runnc                 13                 35705.43
# 24    runsc                  1                  7681.28
# 25    runsc                  2                  8467.62
# 26    runsc                  3                  9711.20
# 27    runsc                  5                 10325.82
# 28    runsc                  8                  9069.69
# 29    runsc                 13                  9337.12
#     runtime  number_of_targets  max_requests_per_second
# 0   default                  1                 22048.57
# 1   default                  2                 27060.35
# 2   default                  3                 26442.21
# 3   default                  5                 25157.12
# 4   default                  8                 25313.50
# 5   default                 13                 25550.80
# 6      kata                  1                 16753.91
# 7      kata                  2                 31804.81
# 8      kata                  3                 31807.45
# 9      kata                  5                 33761.93
# 10     kata                  8                 37886.63
# 11     kata                 13                 44423.17
# 12   katafc                  1                 10310.70
# 13   katafc                  2                 17571.61
# 14   katafc                  3                 20730.22
# 15   katafc                  5                 28575.05
# 16   katafc                  8                 23816.05
# 17   katafc                 13                 21777.08
# 18    runnc                  1                  7717.63
# 19    runnc                  2                 15072.41
# 20    runnc                  3                 22156.58
# 21    runnc                  5                 31540.04
# 22    runnc                  8                 32990.62
# 23    runnc                 13                 36551.02
# 24    runsc                  1                  7793.28
# 25    runsc                  2                  8596.68
# 26    runsc                  3                  9833.45
# 27    runsc                  5                 10722.17
# 28    runsc                  8                  9222.68
# 29    runsc                 13                  9526.62

# %%
# Filter auf default

default_sum = grouped_sum[grouped_sum['runtime'] == 'default']
default_sum = default_sum[['number_of_targets', 'mean_requests_per_second']]
print(default_sum)

default_min = grouped_min[grouped_min['runtime'] == 'default']
default_min = default_min[['number_of_targets', 'min_requests_per_second']]
print(default_min)

default_max = grouped_max[grouped_max['runtime'] == 'default']
default_max = default_max[['number_of_targets', 'max_requests_per_second']]
print(default_max)

default_data = pd.merge(default_sum, default_min, on='number_of_targets')
default_data = pd.merge(default_data, default_max, how='outer', on='number_of_targets')
print(default_data)


# Filter auf kata

kata_sum = grouped_sum[grouped_sum['runtime'] == 'kata']
kata_sum = kata_sum[['number_of_targets', 'mean_requests_per_second']]
print(kata_sum)

kata_min = grouped_min[grouped_min['runtime'] == 'kata']
kata_min = kata_min[['number_of_targets', 'min_requests_per_second']]
print(kata_min)

kata_max = grouped_max[grouped_max['runtime'] == 'kata']
kata_max = kata_max[['number_of_targets', 'max_requests_per_second']]
print(kata_max)

kata_data = pd.merge(kata_sum, kata_min, on='number_of_targets')
kata_data = pd.merge(kata_data, kata_max, how='outer', on='number_of_targets')
print(kata_data)

# Filter auf katafc

katafc_sum = grouped_sum[grouped_sum['runtime'] == 'katafc']
katafc_sum = katafc_sum[['number_of_targets', 'mean_requests_per_second']]
print(katafc_sum)

katafc_min = grouped_min[grouped_min['runtime'] == 'katafc']
katafc_min = katafc_min[['number_of_targets', 'min_requests_per_second']]
print(katafc_min)

katafc_max = grouped_max[grouped_max['runtime'] == 'katafc']
katafc_max = katafc_max[['number_of_targets', 'max_requests_per_second']]
print(katafc_max)

katafc_data = pd.merge(katafc_sum, katafc_min, on='number_of_targets')
katafc_data = pd.merge(katafc_data, katafc_max, how='outer', on='number_of_targets')
print(katafc_data)

# Filter auf runsc

runsc_sum = grouped_sum[grouped_sum['runtime'] == 'runsc']
runsc_sum = runsc_sum[['number_of_targets', 'mean_requests_per_second']]
print(runsc_sum)

runsc_min = grouped_min[grouped_min['runtime'] == 'runsc']
runsc_min = runsc_min[['number_of_targets', 'min_requests_per_second']]
print(runsc_min)

runsc_max = grouped_max[grouped_max['runtime'] == 'runsc']
runsc_max = runsc_max[['number_of_targets', 'max_requests_per_second']]
print(runsc_max)

runsc_data = pd.merge(runsc_sum, runsc_min, on='number_of_targets')
runsc_data = pd.merge(runsc_data, runsc_max, how='outer', on='number_of_targets')
print(runsc_data)

# Filter auf runnc

runnc_sum = grouped_sum[grouped_sum['runtime'] == 'runnc']
runnc_sum = runnc_sum[['number_of_targets', 'mean_requests_per_second']]
print(runnc_sum)

runnc_min = grouped_min[grouped_min['runtime'] == 'runnc']
runnc_min = runnc_min[['number_of_targets', 'min_requests_per_second']]
print(runnc_min)

runnc_max = grouped_max[grouped_max['runtime'] == 'runnc']
runnc_max = runnc_max[['number_of_targets', 'max_requests_per_second']]
print(runnc_max)

runnc_data = pd.merge(runnc_sum, runnc_min, on='number_of_targets')
runnc_data = pd.merge(runnc_data, runnc_max, how='outer', on='number_of_targets')
print(runnc_data)
# Out:
#    number_of_targets  mean_requests_per_second
# 0                  1                 21762.442
# 1                  2                 26943.709
# 2                  3                 26153.097
# 3                  5                 25048.429
# 4                  8                 25206.350
# 5                 13                 25201.639
#    number_of_targets  min_requests_per_second
# 0                  1                 21242.61
# 1                  2                 26893.69
# 2                  3                 26009.76
# 3                  5                 24963.31
# 4                  8                 25040.27
# 5                 13                 24933.09
#    number_of_targets  max_requests_per_second
# 0                  1                 22048.57
# 1                  2                 27060.35
# 2                  3                 26442.21
# 3                  5                 25157.12
# 4                  8                 25313.50
# 5                 13                 25550.80
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                 21762.442                 21242.61
# 1                  2                 26943.709                 26893.69
# 2                  3                 26153.097                 26009.76
# 3                  5                 25048.429                 24963.31
# 4                  8                 25206.350                 25040.27
# 5                 13                 25201.639                 24933.09
#
#    max_requests_per_second
# 0                 22048.57
# 1                 27060.35
# 2                 26442.21
# 3                 25157.12
# 4                 25313.50
# 5                 25550.80
#     number_of_targets  mean_requests_per_second
# 6                   1                 16338.205
# 7                   2                 31610.695
# 8                   3                 31549.669
# 9                   5                 33114.912
# 10                  8                 37281.530
# 11                 13                 44102.552
#     number_of_targets  min_requests_per_second
# 6                   1                 15518.60
# 7                   2                 31096.62
# 8                   3                 31103.63
# 9                   5                 32769.56
# 10                  8                 36378.81
# 11                 13                 43515.25
#     number_of_targets  max_requests_per_second
# 6                   1                 16753.91
# 7                   2                 31804.81
# 8                   3                 31807.45
# 9                   5                 33761.93
# 10                  8                 37886.63
# 11                 13                 44423.17
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                 16338.205                 15518.60
# 1                  2                 31610.695                 31096.62
# 2                  3                 31549.669                 31103.63
# 3                  5                 33114.912                 32769.56
# 4                  8                 37281.530                 36378.81
# 5                 13                 44102.552                 43515.25
#
#    max_requests_per_second
# 0                 16753.91
# 1                 31804.81
# 2                 31807.45
# 3                 33761.93
# 4                 37886.63
# 5                 44423.17
#     number_of_targets  mean_requests_per_second
# 12                  1                 10096.745
# 13                  2                 17490.331
# 14                  3                 20233.842
# 15                  5                 28235.353
# 16                  8                 23497.282
# 17                 13                 21313.104
#     number_of_targets  min_requests_per_second
# 12                  1                  9361.14
# 13                  2                 17339.26
# 14                  3                 19863.23
# 15                  5                 27818.57
# 16                  8                 23103.44
# 17                 13                 21063.02
#     number_of_targets  max_requests_per_second
# 12                  1                 10310.70
# 13                  2                 17571.61
# 14                  3                 20730.22
# 15                  5                 28575.05
# 16                  8                 23816.05
# 17                 13                 21777.08
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                 10096.745                  9361.14
# 1                  2                 17490.331                 17339.26
# 2                  3                 20233.842                 19863.23
# 3                  5                 28235.353                 27818.57
# 4                  8                 23497.282                 23103.44
# 5                 13                 21313.104                 21063.02
#
#    max_requests_per_second
# 0                 10310.70
# 1                 17571.61
# 2                 20730.22
# 3                 28575.05
# 4                 23816.05
# 5                 21777.08
#     number_of_targets  mean_requests_per_second
# 24                  1                  7735.627
# 25                  2                  8539.665
# 26                  3                  9754.796
# 27                  5                 10538.674
# 28                  8                  9159.636
# 29                 13                  9435.927
#     number_of_targets  min_requests_per_second
# 24                  1                  7681.28
# 25                  2                  8467.62
# 26                  3                  9711.20
# 27                  5                 10325.82
# 28                  8                  9069.69
# 29                 13                  9337.12
#     number_of_targets  max_requests_per_second
# 24                  1                  7793.28
# 25                  2                  8596.68
# 26                  3                  9833.45
# 27                  5                 10722.17
# 28                  8                  9222.68
# 29                 13                  9526.62
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                  7735.627                  7681.28
# 1                  2                  8539.665                  8467.62
# 2                  3                  9754.796                  9711.20
# 3                  5                 10538.674                 10325.82
# 4                  8                  9159.636                  9069.69
# 5                 13                  9435.927                  9337.12
#
#    max_requests_per_second
# 0                  7793.28
# 1                  8596.68
# 2                  9833.45
# 3                 10722.17
# 4                  9222.68
# 5                  9526.62
#     number_of_targets  mean_requests_per_second
# 18                  1                  7575.650
# 19                  2                 15008.170
# 20                  3                 22012.353
# 21                  5                 31348.574
# 22                  8                 32705.744
# 23                 13                 36084.286
#     number_of_targets  min_requests_per_second
# 18                  1                  7466.13
# 19                  2                 14939.23
# 20                  3                 21899.77
# 21                  5                 31175.01
# 22                  8                 32455.10
# 23                 13                 35705.43
#     number_of_targets  max_requests_per_second
# 18                  1                  7717.63
# 19                  2                 15072.41
# 20                  3                 22156.58
# 21                  5                 31540.04
# 22                  8                 32990.62
# 23                 13                 36551.02
#    number_of_targets  mean_requests_per_second  min_requests_per_second  \
# 0                  1                  7575.650                  7466.13
# 1                  2                 15008.170                 14939.23
# 2                  3                 22012.353                 21899.77
# 3                  5                 31348.574                 31175.01
# 4                  8                 32705.744                 32455.10
# 5                 13                 36084.286                 35705.43
#
#    max_requests_per_second
# 0                  7717.63
# 1                 15072.41
# 2                 22156.58
# 3                 31540.04
# 4                 32990.62
# 5                 36551.02

# %%
default_source = ColumnDataSource(default_data)
print(default_source.data)

kata_source = ColumnDataSource(kata_data)
print(kata_source.data)

katafc_source = ColumnDataSource(katafc_data)
print(katafc_source.data)

runsc_source = ColumnDataSource(runsc_data)
print(runsc_source.data)

runnc_source = ColumnDataSource(runnc_data)
print(runnc_source.data)
# Out:
# {'index': array([0, 1, 2, 3, 4, 5]), 'number_of_targets': array([ 1,  2,  3,  5,  8, 13]), 'mean_requests_per_second': array([21762.442, 26943.709, 26153.097, 25048.429, 25206.35 , 25201.639]), 'min_requests_per_second': array([21242.61, 26893.69, 26009.76, 24963.31, 25040.27, 24933.09]), 'max_requests_per_second': array([22048.57, 27060.35, 26442.21, 25157.12, 25313.5 , 25550.8 ])}
# {'index': array([0, 1, 2, 3, 4, 5]), 'number_of_targets': array([ 1,  2,  3,  5,  8, 13]), 'mean_requests_per_second': array([16338.205, 31610.695, 31549.669, 33114.912, 37281.53 , 44102.552]), 'min_requests_per_second': array([15518.6 , 31096.62, 31103.63, 32769.56, 36378.81, 43515.25]), 'max_requests_per_second': array([16753.91, 31804.81, 31807.45, 33761.93, 37886.63, 44423.17])}
# {'index': array([0, 1, 2, 3, 4, 5]), 'number_of_targets': array([ 1,  2,  3,  5,  8, 13]), 'mean_requests_per_second': array([10096.745, 17490.331, 20233.842, 28235.353, 23497.282, 21313.104]), 'min_requests_per_second': array([ 9361.14, 17339.26, 19863.23, 27818.57, 23103.44, 21063.02]), 'max_requests_per_second': array([10310.7 , 17571.61, 20730.22, 28575.05, 23816.05, 21777.08])}
# {'index': array([0, 1, 2, 3, 4, 5]), 'number_of_targets': array([ 1,  2,  3,  5,  8, 13]), 'mean_requests_per_second': array([ 7735.627,  8539.665,  9754.796, 10538.674,  9159.636,  9435.927]), 'min_requests_per_second': array([ 7681.28,  8467.62,  9711.2 , 10325.82,  9069.69,  9337.12]), 'max_requests_per_second': array([ 7793.28,  8596.68,  9833.45, 10722.17,  9222.68,  9526.62])}
# {'index': array([0, 1, 2, 3, 4, 5]), 'number_of_targets': array([ 1,  2,  3,  5,  8, 13]), 'mean_requests_per_second': array([ 7575.65 , 15008.17 , 22012.353, 31348.574, 32705.744, 36084.286]), 'min_requests_per_second': array([ 7466.13, 14939.23, 21899.77, 31175.01, 32455.1 , 35705.43]), 'max_requests_per_second': array([ 7717.63, 15072.41, 22156.58, 31540.04, 32990.62, 36551.02])}

# %%
p = figure(x_axis_type='linear', width=1500)

# Linien für default runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][1], fill_alpha=0.3)
p.add_glyph(default_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=default_source, color=bokeh.palettes.d3['Category20'][12][0], legend_label='default (Docker)')

# Linien für kata runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][2], fill_alpha=0.3)
p.add_glyph(kata_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=kata_source, color=bokeh.palettes.d3['Category20'][12][3], legend_label='kata')

# Linien für katafc runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][4], fill_alpha=0.3)
p.add_glyph(katafc_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=katafc_source, color=bokeh.palettes.d3['Category20'][12][5], legend_label='katafc')

# Linien für runsc runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][6], fill_alpha=0.3)
p.add_glyph(runsc_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=runsc_source, color=bokeh.palettes.d3['Category20'][12][7], legend_label='runsc (gVisor)')

# Linien für runnc runtime
glyph = VArea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', fill_color=bokeh.palettes.d3['Category20'][12][8], fill_alpha=0.3)
p.add_glyph(runnc_source, glyph)
p.line(x='number_of_targets', y='mean_requests_per_second', line_width=2, source=runnc_source, color=bokeh.palettes.d3['Category20'][12][9], legend_label='runnc (Nabla)')


#p.line(x='number_of_targets', y='min_requests_per_second', line_width=2, source=default_source, color=bokeh.palettes.d3['Category20c'][12][2], legend_label='default-min')
#p.line(x='number_of_targets', y='max_requests_per_second', line_width=2, source=default_source, color=bokeh.palettes.d3['Category20c'][12][3], legend_label='default-max')

#p.varea(x='number_of_targets', y1='min_requests_per_second', y2='max_requests_per_second', source=default_source)



colors = bokeh.palettes.d3['Category20c'][12]

p.title.text ='Requests pro Sekunde nach Anzahl der parellen Container für go_http'
p.xaxis.axis_label = 'Anzahl an parallelen Containern'
p.yaxis.axis_label = 'Requests pro Sekunde'

output_file("requests_pro_sec_anzahl_container_go_http.html")
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1602">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d96a71b1-7a0d-4955-855b-eb801c84dca9" data-root-id="1458"></div>
